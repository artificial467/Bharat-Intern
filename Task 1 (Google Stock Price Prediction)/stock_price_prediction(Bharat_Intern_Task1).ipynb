# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
google_stock_data = pd.read_csv('/content/GOOG.csv')
google_stock_data.head()
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
google_stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
google_stock_data = google_stock_data[['date','open','close']]
# Extracting required columns
google_stock_data['date'] = pd.to_datetime(google_stock_data['date'].apply(lambda x: x.split()[0]))
 # Selecting only date
google_stock_data.set_index('date',drop=True,inplace=True)
# Setting date column as index
google_stock_data.head()
# Out:
# <ipython-input-4-3d1443e590ba>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   google_stock_data['date'] = pd.to_datetime(google_stock_data['date'].apply(lambda x: x.split()[0])) # Selecting only date
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71

# %%
fg, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(google_stock_data['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(google_stock_data['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fg.show()

# %% [markdown]
#  ## **Data Pre-Processing**

# %%
from sklearn.preprocessing import MinMaxScaler
MMS = MinMaxScaler()
google_stock_data[google_stock_data.columns] = MMS.fit_transform(google_stock_data)

# %%
google_stock_data.shape
# Out:
# (1258, 2)

# %%
training_size = round(len(google_stock_data) * 0.80) # Selecting 80 % for training and 20 % for testing
training_size
# Out:
# 1006

# %%
train_data = google_stock_data[:training_size]
test_data  = google_stock_data[training_size:]

train_data.shape, test_data.shape
# Out:
# ((1006, 2), (252, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)

# %%
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((956, 50, 2), (956, 2), (202, 50, 2), (202, 2))

# %% [markdown]
# ## **Creating LSTM Model**

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30,902
# Trainable params: 30,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=80,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/80
# 30/30 [==============================] - 8s 91ms/step - loss: 0.0093 - mean_absolute_error: 0.0692 - val_loss: 0.0277 - val_mean_absolute_error: 0.1481
# Epoch 2/80
# 30/30 [==============================] - 3s 88ms/step - loss: 0.0011 - mean_absolute_error: 0.0269 - val_loss: 0.0058 - val_mean_absolute_error: 0.0620
# Epoch 3/80
# 30/30 [==============================] - 2s 80ms/step - loss: 5.3812e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0028 - val_mean_absolute_error: 0.0416
# Epoch 4/80
# 30/30 [==============================] - 2s 57ms/step - loss: 4.8863e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0035 - val_mean_absolute_error: 0.0469
# Epoch 5/80
# 30/30 [==============================] - 2s 58ms/step - loss: 4.5653e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0034 - val_mean_absolute_error: 0.0467
# Epoch 6/80
# 30/30 [==============================] - 2s 56ms/step - loss: 4.3885e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0031 - val_mean_absolute_error: 0.0442
# Epoch 7/80
# 30/30 [==============================] - 2s 56ms/step - loss: 4.3574e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0036 - val_mean_absolute_error: 0.0478
# Epoch 8/80
# 30/30 [==============================] - 2s 59ms/step - loss: 4.3793e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0037 - val_mean_absolute_error: 0.0494
# Epoch 9/80
# 30/30 [==============================] - 3s 94ms/step - loss: 4.3369e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0045 - val_mean_absolute_error: 0.0557
# Epoch 10/80
# 30/30 [==============================] - 2s 56ms/step - loss: 4.0474e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0026 - val_mean_absolute_error: 0.0401
# Epoch 11/80
# 30/30 [==============================] - 2s 57ms/step - loss: 3.8428e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0028 - val_mean_absolute_error: 0.0410
# Epoch 12/80
# 30/30 [==============================] - 2s 58ms/step - loss: 3.6807e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0052 - val_mean_absolute_error: 0.0597
# Epoch 13/80
# 30/30 [==============================] - 2s 56ms/step - loss: 3.4459e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0060 - val_mean_absolute_error: 0.0652
# Epoch 14/80
# 30/30 [==============================] - 5s 166ms/step - loss: 3.5806e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0025 - val_mean_absolute_error: 0.0384
# Epoch 15/80
# 30/30 [==============================] - 5s 159ms/step - loss: 3.5389e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0057 - val_mean_absolute_error: 0.0624
# Epoch 16/80
# 30/30 [==============================] - 4s 128ms/step - loss: 3.4836e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0044 - val_mean_absolute_error: 0.0522
# Epoch 17/80
# 30/30 [==============================] - 4s 139ms/step - loss: 3.2420e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0073 - val_mean_absolute_error: 0.0712
# Epoch 18/80
# 30/30 [==============================] - 4s 126ms/step - loss: 3.3777e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0053 - val_mean_absolute_error: 0.0584
# Epoch 19/80
# 30/30 [==============================] - 3s 83ms/step - loss: 3.1583e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0087 - val_mean_absolute_error: 0.0787
# Epoch 20/80
# 30/30 [==============================] - 4s 139ms/step - loss: 3.1044e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0082 - val_mean_absolute_error: 0.0755
# Epoch 21/80
# 30/30 [==============================] - 2s 55ms/step - loss: 3.1767e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0115 - val_mean_absolute_error: 0.0923
# Epoch 22/80
# 30/30 [==============================] - 3s 118ms/step - loss: 3.1997e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0078 - val_mean_absolute_error: 0.0727
# Epoch 23/80
# 30/30 [==============================] - 2s 76ms/step - loss: 3.0940e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0076 - val_mean_absolute_error: 0.0725
# Epoch 24/80
# 30/30 [==============================] - 3s 93ms/step - loss: 3.0211e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0076 - val_mean_absolute_error: 0.0721
# Epoch 25/80
# 30/30 [==============================] - 2s 82ms/step - loss: 2.7320e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0047 - val_mean_absolute_error: 0.0533
# Epoch 26/80
# 30/30 [==============================] - 2s 57ms/step - loss: 3.1872e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0069 - val_mean_absolute_error: 0.0669
# Epoch 27/80
# 30/30 [==============================] - 3s 95ms/step - loss: 2.7705e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0059 - val_mean_absolute_error: 0.0620
# Epoch 28/80
# 30/30 [==============================] - 3s 85ms/step - loss: 2.6041e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0046 - val_mean_absolute_error: 0.0530
# Epoch 29/80
# 30/30 [==============================] - 2s 79ms/step - loss: 2.6300e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0062 - val_mean_absolute_error: 0.0642
# Epoch 30/80
# 30/30 [==============================] - 3s 94ms/step - loss: 2.6151e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0058 - val_mean_absolute_error: 0.0621
# Epoch 31/80
# 30/30 [==============================] - 3s 95ms/step - loss: 2.5354e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0055 - val_mean_absolute_error: 0.0600
# Epoch 32/80
# 30/30 [==============================] - 4s 141ms/step - loss: 2.6321e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0066 - val_mean_absolute_error: 0.0667
# Epoch 33/80
# 30/30 [==============================] - 4s 125ms/step - loss: 2.5712e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0073 - val_mean_absolute_error: 0.0701
# Epoch 34/80
# 30/30 [==============================] - 3s 110ms/step - loss: 2.5669e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0049 - val_mean_absolute_error: 0.0548
# Epoch 35/80
# 30/30 [==============================] - 4s 137ms/step - loss: 2.4233e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0039 - val_mean_absolute_error: 0.0480
# Epoch 36/80
# 30/30 [==============================] - 4s 132ms/step - loss: 2.5125e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0034 - val_mean_absolute_error: 0.0449
# Epoch 37/80
# 30/30 [==============================] - 3s 95ms/step - loss: 2.3851e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0039 - val_mean_absolute_error: 0.0481
# Epoch 38/80
# 30/30 [==============================] - 2s 80ms/step - loss: 2.4000e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0028 - val_mean_absolute_error: 0.0399
# Epoch 39/80
# 30/30 [==============================] - 3s 83ms/step - loss: 2.3110e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0050 - val_mean_absolute_error: 0.0562
# Epoch 40/80
# 30/30 [==============================] - 4s 121ms/step - loss: 2.2335e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0040 - val_mean_absolute_error: 0.0490
# Epoch 41/80
# 30/30 [==============================] - 2s 74ms/step - loss: 2.3866e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0042 - val_mean_absolute_error: 0.0505
# Epoch 42/80
# 30/30 [==============================] - 2s 58ms/step - loss: 2.5751e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0027 - val_mean_absolute_error: 0.0391
# Epoch 43/80
# 30/30 [==============================] - 3s 88ms/step - loss: 2.1640e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0037 - val_mean_absolute_error: 0.0467
# Epoch 44/80
# 30/30 [==============================] - 2s 82ms/step - loss: 2.2174e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0055 - val_mean_absolute_error: 0.0609
# Epoch 45/80
# 30/30 [==============================] - 4s 124ms/step - loss: 2.2957e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0040 - val_mean_absolute_error: 0.0499
# Epoch 46/80
# 30/30 [==============================] - 2s 77ms/step - loss: 2.0857e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0038 - val_mean_absolute_error: 0.0484
# Epoch 47/80
# 30/30 [==============================] - 2s 81ms/step - loss: 2.1739e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0051 - val_mean_absolute_error: 0.0572
# Epoch 48/80
# 30/30 [==============================] - 2s 72ms/step - loss: 2.1276e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0065 - val_mean_absolute_error: 0.0667
# Epoch 49/80
# 30/30 [==============================] - 2s 62ms/step - loss: 2.1373e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0049 - val_mean_absolute_error: 0.0562
# Epoch 50/80
# 30/30 [==============================] - 3s 95ms/step - loss: 1.8856e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0058 - val_mean_absolute_error: 0.0605
# Epoch 51/80
# 30/30 [==============================] - 3s 87ms/step - loss: 2.0410e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0085 - val_mean_absolute_error: 0.0766
# Epoch 52/80
# 30/30 [==============================] - 2s 77ms/step - loss: 2.1852e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0079 - val_mean_absolute_error: 0.0742
# Epoch 53/80
# 30/30 [==============================] - 2s 81ms/step - loss: 2.0250e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0073 - val_mean_absolute_error: 0.0704
# Epoch 54/80
# 30/30 [==============================] - 2s 74ms/step - loss: 2.1116e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0040 - val_mean_absolute_error: 0.0491
# Epoch 55/80
# 30/30 [==============================] - 3s 86ms/step - loss: 1.7582e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0039 - val_mean_absolute_error: 0.0467
# Epoch 56/80
# 30/30 [==============================] - 3s 112ms/step - loss: 1.9514e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0058 - val_mean_absolute_error: 0.0608
# Epoch 57/80
# 30/30 [==============================] - 2s 61ms/step - loss: 1.7711e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0040 - val_mean_absolute_error: 0.0478
# Epoch 58/80
# 30/30 [==============================] - 2s 58ms/step - loss: 1.7808e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0023 - val_mean_absolute_error: 0.0361
# Epoch 59/80
# 30/30 [==============================] - 2s 71ms/step - loss: 1.7749e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0039 - val_mean_absolute_error: 0.0491
# Epoch 60/80
# 30/30 [==============================] - 2s 72ms/step - loss: 1.7614e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0061 - val_mean_absolute_error: 0.0619
# Epoch 61/80
# 30/30 [==============================] - 4s 124ms/step - loss: 1.9664e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0058 - val_mean_absolute_error: 0.0604
# Epoch 62/80
# 30/30 [==============================] - 2s 66ms/step - loss: 1.7238e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0060 - val_mean_absolute_error: 0.0597
# Epoch 63/80
# 30/30 [==============================] - 2s 62ms/step - loss: 1.5654e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0041 - val_mean_absolute_error: 0.0484
# Epoch 64/80
# 30/30 [==============================] - 2s 58ms/step - loss: 1.5980e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0031 - val_mean_absolute_error: 0.0402
# Epoch 65/80
# 30/30 [==============================] - 2s 57ms/step - loss: 1.8408e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0039 - val_mean_absolute_error: 0.0460
# Epoch 66/80
# 30/30 [==============================] - 2s 57ms/step - loss: 1.5532e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0062 - val_mean_absolute_error: 0.0628
# Epoch 67/80
# 30/30 [==============================] - 2s 59ms/step - loss: 1.6405e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0068 - val_mean_absolute_error: 0.0655
# Epoch 68/80
# 30/30 [==============================] - 3s 96ms/step - loss: 1.5157e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0047 - val_mean_absolute_error: 0.0488
# Epoch 69/80
# 30/30 [==============================] - 2s 58ms/step - loss: 1.6329e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0037 - val_mean_absolute_error: 0.0434
# Epoch 70/80
# 30/30 [==============================] - 2s 60ms/step - loss: 1.5307e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0055 - val_mean_absolute_error: 0.0582
# Epoch 71/80
# 30/30 [==============================] - 2s 59ms/step - loss: 1.4245e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0053 - val_mean_absolute_error: 0.0571
# Epoch 72/80
# 30/30 [==============================] - 2s 58ms/step - loss: 1.5933e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0055 - val_mean_absolute_error: 0.0569
# Epoch 73/80
# 30/30 [==============================] - 2s 59ms/step - loss: 1.3955e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0045 - val_mean_absolute_error: 0.0478
# Epoch 74/80
# 30/30 [==============================] - 2s 69ms/step - loss: 1.4194e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0058 - val_mean_absolute_error: 0.0614
# Epoch 75/80
# 30/30 [==============================] - 3s 87ms/step - loss: 1.5061e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0041 - val_mean_absolute_error: 0.0471
# Epoch 76/80
# 30/30 [==============================] - 2s 58ms/step - loss: 1.3603e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0050 - val_mean_absolute_error: 0.0528
# Epoch 77/80
# 30/30 [==============================] - 2s 58ms/step - loss: 1.3814e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0045 - val_mean_absolute_error: 0.0496
# Epoch 78/80
# 30/30 [==============================] - 2s 57ms/step - loss: 1.4471e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0066 - val_mean_absolute_error: 0.0636
# Epoch 79/80
# 30/30 [==============================] - 3s 92ms/step - loss: 1.4439e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0061 - val_mean_absolute_error: 0.0589
# Epoch 80/80
# 30/30 [==============================] - 4s 121ms/step - loss: 1.2970e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0047 - val_mean_absolute_error: 0.0525

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 7/7 [==============================] - 1s 24ms/step
# array([[0.48043075, 0.48419458],
#        [0.48677638, 0.49094456],
#        [0.49158093, 0.4961751 ],
#        [0.50757813, 0.51162785],
#        [0.5178925 , 0.52213085]], dtype=float32)

# %%
#Inversing scaling on predicted data
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1561.6802, 1565.6372],
#        [1573.4445, 1578.1472],
#        [1582.3517, 1587.8412],
#        [1612.0093, 1616.4805],
#        [1631.1312, 1635.946 ]], dtype=float32)

# %% [markdown]
# ## Visualizing Predicted and Actual data

# %%
# Merging actual and predicted data for better visualization
gs_slic_data = pd.concat([google_stock_data.iloc[-202:].copy(),pd.DataFrame(test_inverse_predicted, columns=['open_predicted','close_predicted'],index=google_stock_data.iloc[-202:].index)], axis=1)

# %%
# Inversing Scale
gs_slic_data[['open','close']] = MMS.inverse_transform(gs_slic_data[['open','close']])

# %%
gs_slic_data.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-08-24  1593.98  1588.20     1561.680176      1565.637207
# 2020-08-25  1582.07  1608.22     1573.444458      1578.147217
# 2020-08-26  1608.00  1652.38     1582.351685      1587.841187
# 2020-08-27  1653.68  1634.33     1612.009277      1616.480469
# 2020-08-28  1633.49  1644.41     1631.131226      1635.946045

# %%
gs_slic_data[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
gs_slic_data[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# ## Predicting Upcoming 10 Days

# %%
# Creating a dataframe and adding 10 days to existing index

gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))
# Out:
# <ipython-input-31-3796df6ba6f4>:3: FutureWarning: Argument `closed` is deprecated in favor of `inclusive`.
#   gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))
# <ipython-input-31-3796df6ba6f4>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))

# %%
gs_slic_data['2021-06-09	':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2320.177002      2197.455078
# 2021-06-10  2494.01  2521.60     2333.032715      2208.064209
# 2021-06-11  2524.92  2513.93     2345.995117      2218.124023
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns = ['open','close'],index=gs_slic_data.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]
for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i]=up_pred
  curr_seq = np.append(curr_seq[0][1:], up_pred, axis = 0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fg, ax = plt.subplots(figsize = (10,5))
ax.plot(gs_slic_data.loc['2021-04-01':, 'open'],label = 'Current Open Price')

ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 45)
ax.set_xlabel('Date', size = 15)
ax.set_ylabel('Stock Price', size=15)
ax.set_title('Upcoming Open Price Prediction',size =15)
ax.legend()
fg.show()

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fg.show()
